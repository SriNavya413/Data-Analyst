# %% [markdown]
# <a href="https://colab.research.google.com/github/SriNavya413/Data-Analyst/blob/main/Project_2__(9_12_2024).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import pandas as pd
import json

# Try reading the file with the 'lines' argument if it's line-delimited JSON
try:
    data = pd.read_json('/content/dataset_1 (1).json', lines=True)
except ValueError:
    # If that fails, try opening the file, cleaning the JSON string, and then reading it
    with open('/content/dataset_1 (1).json', 'r') as f:
        # Load the JSON data, handling potential decoding issues
        try:
            json_data = json.load(f)
        except json.JSONDecodeError as e:
            print(f"JSONDecodeError: {e}")
            # If decoding fails, try to fix common issues like extra data:
            # This is a simple fix for trailing data, you might need more robust logic
            # depending on the specific error.
            from ast import literal_eval
            # Try to extract the valid JSON part using literal_eval
            json_data = literal_eval(f.read().strip()[:-1])

    # Try reading the cleaned JSON data into a DataFrame
    try:
        data = pd.DataFrame(json_data)
    except (TypeError, ValueError) as e:
        print(f"Error creating DataFrame: {e}, the JSON data may not be in the expected format.")
        # For complex JSON structures, you might need to adjust this logic to
        # handle nested objects or arrays. Try json_normalize or other techniques.

# %%
data
# Out:
#                                                      url      make_model  \
# 0      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 1      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 2      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 3      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 4      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# ...                                                  ...             ...
# 15914  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15915  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15916  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15917  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15918  https://www.autoscout24.com//offers/renault-es...  Renault Espace
#
#                                        short_description body_type  price  \
# 0            Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1                                         1.8 TFSI sport    Sedans  14500
# 2      Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans  14640
# 3                                1.4 TDi Design S tronic    Sedans  14500
# 4      Sportback 1.4 TDI S-Tronic S-Line Ext. admired...    Sedans  16790
# ...                                                  ...       ...    ...
# 15914              Blue dCi 200CV EDC Executive 4Control       Van  39950
# 15915                TCe 225 EDC GPF LIM Deluxe Pano,RFK       Van  39885
# 15916  Blue dCi 200 EDC Initiale Paris Leder LED Navi...       Van  39875
# 15917  Blue dCi 200CV EDC Business , NUOVA DA IMMATRI...       Van  39700
# 15918        INITIALE PARIS TCe 225 EDC GPF NAVI SHZ AUX       Van  40999
#
#                     vat         km registration         prev_owner  kW  ...  \
# 0        VAT deductible  56,013 km      01/2016  2 previous owners NaN  ...
# 1      Price negotiable  80,000 km      03/2017               None NaN  ...
# 2        VAT deductible  83,450 km      02/2016   1 previous owner NaN  ...
# 3                  None  73,000 km      08/2016   1 previous owner NaN  ...
# 4                  None  16,200 km      05/2016   1 previous owner NaN  ...
# ...                 ...        ...          ...                ...  ..  ...
# 15914    VAT deductible       - km          -/-               None NaN  ...
# 15915    VAT deductible   9,900 km      01/2019   1 previous owner NaN  ...
# 15916    VAT deductible      15 km      03/2019   1 previous owner NaN  ...
# 15917    VAT deductible      10 km      06/2019               None NaN  ...
# 15918    VAT deductible       - km      01/2019   1 previous owner NaN  ...
#
#                                              description   Emission Label  \
# 0      [\n, Sicherheit:,  , Deaktivierung für Beifahr...              NaN
# 1      [\nLangstreckenfahrzeug daher die hohe Kilomet...  [\n4 (Green)\n]
# 2      [\n, Fahrzeug-Nummer: AM-95365,  , Ehem. UPE 2...  [\n4 (Green)\n]
# 3      [\nAudi A1: , - 1e eigenaar , - Perfecte staat...              NaN
# 4      [\n, Technik & Sicherheit:, Xenon plus, Klimaa...              NaN
# ...                                                  ...              ...
# 15914  [\nVettura visionabile nella sede in Via Roma ...              NaN
# 15915  [\nDach: Panorama-Glas-Schiebedach, Lackierung...              NaN
# 15916  [\n, Getriebe:,  Automatik, Technik:,  Bordcom...              NaN
# 15917  [\nDEK:[2691331], Renault Espace Blue dCi 200C...              NaN
# 15918  [\n, Sicherheit Airbags:,  , Seitenairbag,  , ...  [\n4 (Green)\n]
#
#          Gears Country version Electricity consumption Last Service Date  \
# 0          NaN             NaN                     NaN               NaN
# 1      [\n7\n]             NaN                     NaN               NaN
# 2          NaN             NaN                     NaN               NaN
# 3      [\n6\n]             NaN                     NaN               NaN
# 4          NaN   [\nGermany\n]                     NaN               NaN
# ...        ...             ...                     ...               ...
# 15914  [\n6\n]             NaN                     NaN               NaN
# 15915  [\n7\n]   [\nGermany\n]                     NaN               NaN
# 15916  [\n6\n]   [\nAustria\n]                     NaN               NaN
# 15917  [\n6\n]             NaN                     NaN               NaN
# 15918      NaN   [\nGermany\n]                     NaN               NaN
#
#       Other Fuel Types                   Availability  \
# 0                  NaN                            NaN
# 1                  NaN                            NaN
# 2                  NaN                            NaN
# 3                  NaN                            NaN
# 4                  NaN                            NaN
# ...                ...                            ...
# 15914              NaN                            NaN
# 15915     [[], [], []]    \nin 5 days from ordering\n
# 15916              NaN  \nin 120 days from ordering\n
# 15917              NaN                            NaN
# 15918              NaN                            NaN
#
#       Last Timing Belt Service Date Available from
# 0                               NaN            NaN
# 1                               NaN            NaN
# 2                               NaN            NaN
# 3                               NaN            NaN
# 4                               NaN            NaN
# ...                             ...            ...
# 15914                           NaN            NaN
# 15915                           NaN            NaN
# 15916                           NaN            NaN
# 15917                           NaN            NaN
# 15918                           NaN            NaN
#
# [15919 rows x 54 columns]

# %%
from google.colab import files

# Assuming 'data' is your DataFrame
data.to_excel('output2.xlsx', index=False)
files.download('output2.xlsx')

# %%
data1=pd.read_excel('/content/output2.xlsx')

# %%
data1
# Out:
#                                                      url      make_model  \
# 0      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 1      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 2      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 3      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 4      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# ...                                                  ...             ...
# 15914  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15915  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15916  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15917  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15918  https://www.autoscout24.com//offers/renault-es...  Renault Espace
#
#                                        short_description body_type  price  \
# 0            Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1                                         1.8 TFSI sport    Sedans  14500
# 2      Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans  14640
# 3                                1.4 TDi Design S tronic    Sedans  14500
# 4      Sportback 1.4 TDI S-Tronic S-Line Ext. admired...    Sedans  16790
# ...                                                  ...       ...    ...
# 15914              Blue dCi 200CV EDC Executive 4Control       Van  39950
# 15915                TCe 225 EDC GPF LIM Deluxe Pano,RFK       Van  39885
# 15916  Blue dCi 200 EDC Initiale Paris Leder LED Navi...       Van  39875
# 15917  Blue dCi 200CV EDC Business , NUOVA DA IMMATRI...       Van  39700
# 15918        INITIALE PARIS TCe 225 EDC GPF NAVI SHZ AUX       Van  40999
#
#                     vat         km registration         prev_owner  kW  ...  \
# 0        VAT deductible  56,013 km      01/2016  2 previous owners NaN  ...
# 1      Price negotiable  80,000 km      03/2017                NaN NaN  ...
# 2        VAT deductible  83,450 km      02/2016   1 previous owner NaN  ...
# 3                   NaN  73,000 km      08/2016   1 previous owner NaN  ...
# 4                   NaN  16,200 km      05/2016   1 previous owner NaN  ...
# ...                 ...        ...          ...                ...  ..  ...
# 15914    VAT deductible       - km          -/-                NaN NaN  ...
# 15915    VAT deductible   9,900 km      01/2019   1 previous owner NaN  ...
# 15916    VAT deductible      15 km      03/2019   1 previous owner NaN  ...
# 15917    VAT deductible      10 km      06/2019                NaN NaN  ...
# 15918    VAT deductible       - km      01/2019   1 previous owner NaN  ...
#
#                                              description     Emission Label  \
# 0      ['\n', 'Sicherheit:', ' ', 'Deaktivierung für ...                NaN
# 1      ['\nLangstreckenfahrzeug daher die hohe Kilome...  ['\n4 (Green)\n']
# 2      ['\n', 'Fahrzeug-Nummer: AM-95365', ' ', 'Ehem...  ['\n4 (Green)\n']
# 3      ['\nAudi A1: ', '- 1e eigenaar ', '- Perfecte ...                NaN
# 4      ['\n', 'Technik & Sicherheit:', 'Xenon plus', ...                NaN
# ...                                                  ...                ...
# 15914  ['\nVettura visionabile nella sede in Via Roma...                NaN
# 15915  ['\nDach: Panorama-Glas-Schiebedach, Lackierun...                NaN
# 15916  ['\n', 'Getriebe:', ' Automatik', 'Technik:', ...                NaN
# 15917  ['\nDEK:[2691331]', 'Renault Espace Blue dCi 2...                NaN
# 15918  ['\n', 'Sicherheit Airbags:', ' ', 'Seitenairb...  ['\n4 (Green)\n']
#
#            Gears  Country version Electricity consumption Last Service Date  \
# 0            NaN              NaN                     NaN               NaN
# 1      ['\n7\n']              NaN                     NaN               NaN
# 2            NaN              NaN                     NaN               NaN
# 3      ['\n6\n']              NaN                     NaN               NaN
# 4            NaN  ['\nGermany\n']                     NaN               NaN
# ...          ...              ...                     ...               ...
# 15914  ['\n6\n']              NaN                     NaN               NaN
# 15915  ['\n7\n']  ['\nGermany\n']                     NaN               NaN
# 15916  ['\n6\n']  ['\nAustria\n']                     NaN               NaN
# 15917  ['\n6\n']              NaN                     NaN               NaN
# 15918        NaN  ['\nGermany\n']                     NaN               NaN
#
#       Other Fuel Types                   Availability  \
# 0                  NaN                            NaN
# 1                  NaN                            NaN
# 2                  NaN                            NaN
# 3                  NaN                            NaN
# 4                  NaN                            NaN
# ...                ...                            ...
# 15914              NaN                            NaN
# 15915     [[], [], []]    \nin 5 days from ordering\n
# 15916              NaN  \nin 120 days from ordering\n
# 15917              NaN                            NaN
# 15918              NaN                            NaN
#
#       Last Timing Belt Service Date Available from
# 0                               NaN            NaN
# 1                               NaN            NaN
# 2                               NaN            NaN
# 3                               NaN            NaN
# 4                               NaN            NaN
# ...                             ...            ...
# 15914                           NaN            NaN
# 15915                           NaN            NaN
# 15916                           NaN            NaN
# 15917                           NaN            NaN
# 15918                           NaN            NaN
#
# [15919 rows x 54 columns]

# %% [markdown]
# ** Identify and Remove Null or Missing Values**

# %%
# Check for missing values
print("Missing values per column:\n", df.isnull().sum())

# Remove rows with missing values
df = df.dropna()

# Confirm no missing values remain
print("Missing values after removal:\n", df.isnull().sum())
# Out:
# Missing values per column:
#  url                                  0
# make_model                           0
# short_description                   46
# body_type                           60
# price                                0
# vat                               4513
# km                                   0
# registration                         0
# prev_owner                        6828
# kW                               15919
# hp                                   0
# Type                                 2
# Previous Owners                   6640
# Next Inspection                  12384
# Inspection new                   11987
# Warranty                          5420
# Full Service                      7704
# Non-smoking Vehicle               8742
# null                                 0
# Make                                 0
# Model                                0
# Offer Number                      3175
# First Registration                1597
# Body Color                         597
# Paint Type                        5772
# Body Color Original               3759
# Upholstery                        3720
# Body                                60
# Nr. of Doors                       212
# Nr. of Seats                       977
# Model Code                       10941
# Gearing Type                         0
# Displacement                       496
# Cylinders                         5680
# Weight                            6974
# Drive chain                       6858
# Fuel                                 0
# Consumption                       1906
# CO2 Emission                      1808
# Emission Class                    3021
# \nComfort & Convenience\n          920
# \nEntertainment & Media\n         1374
# \nExtras\n                        2962
# \nSafety & Security\n              982
# description                          0
# Emission Label                   11934
# Gears                             4712
# Country version                   8333
# Electricity consumption          15782
# Last Service Date                15353
# Other Fuel Types                 15039
# Availability                     15284
# Last Timing Belt Service Date    15903
# Available from                   15647
# dtype: int64
# Missing values after removal:
#  url                              0
# make_model                       0
# short_description                0
# body_type                        0
# price                            0
# vat                              0
# km                               0
# registration                     0
# prev_owner                       0
# kW                               0
# hp                               0
# Type                             0
# Previous Owners                  0
# Next Inspection                  0
# Inspection new                   0
# Warranty                         0
# Full Service                     0
# Non-smoking Vehicle              0
# null                             0
# Make                             0
# Model                            0
# Offer Number                     0
# First Registration               0
# Body Color                       0
# Paint Type                       0
# Body Color Original              0
# Upholstery                       0
# Body                             0
# Nr. of Doors                     0
# Nr. of Seats                     0
# Model Code                       0
# Gearing Type                     0
# Displacement                     0
# Cylinders                        0
# Weight                           0
# Drive chain                      0
# Fuel                             0
# Consumption                      0
# CO2 Emission                     0
# Emission Class                   0
# \nComfort & Convenience\n        0
# \nEntertainment & Media\n        0
# \nExtras\n                       0
# \nSafety & Security\n            0
# description                      0
# Emission Label                   0
# Gears                            0
# Country version                  0
# Electricity consumption          0
# Last Service Date                0
# Other Fuel Types                 0
# Availability                     0
# Last Timing Belt Service Date    0
# Available from                   0
# dtype: int64

# %% [markdown]
# *** Standardize numerical fields (e.g., price, km) for consistency. ***

# %%
# prompt: write a code for Standardize numerical fields (e.g., price, km) for consistency.

# Assuming 'data1' is your DataFrame and you want to standardize 'price' and 'km'
numerical_cols = ['price', 'km']

for col in numerical_cols:
    if col in data1.columns:  # Check if the column exists
        # Check if the column contains string values
        if data1[col].dtype == 'object':
            try:
                # Try to remove non-numeric characters and convert to numeric
                data1[col] = pd.to_numeric(data1[col].str.replace(r'[^0-9.]', '', regex=True))
            except ValueError:
                print(f"Warning: Column '{col}' contains non-numeric strings that cannot be automatically converted. Please review the data.")
                continue # Skip this column

        # Calculate mean and standard deviation
        mean = data1[col].mean()
        std = data1[col].std()

        # Handle cases where standard deviation is zero to avoid division by zero
        if std == 0:
            print(f"Warning: Standard deviation for column '{col}' is zero. Skipping standardization for this column.")
            continue  # Skip standardization for this column

        # Standardize the column
        data1[col] = (data1[col] - mean) / std
    else:
        print(f"Warning: Column '{col}' not found in DataFrame.")

# Display the DataFrame with standardized columns
data1
# Out:
#                                                      url      make_model  \
# 0      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 1      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 2      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 3      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 4      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# ...                                                  ...             ...
# 15914  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15915  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15916  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15917  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15918  https://www.autoscout24.com//offers/renault-es...  Renault Espace
#
#                                        short_description body_type     price  \
# 0            Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans -0.304609
# 1                                         1.8 TFSI sport    Sedans -0.476552
# 2      Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans -0.457598
# 3                                1.4 TDi Design S tronic    Sedans -0.476552
# 4      Sportback 1.4 TDI S-Tronic S-Line Ext. admired...    Sedans -0.166513
# ...                                                  ...       ...       ...
# 15914              Blue dCi 200CV EDC Executive 4Control       Van  2.969077
# 15915                TCe 225 EDC GPF LIM Deluxe Pano,RFK       Van  2.960276
# 15916  Blue dCi 200 EDC Initiale Paris Leder LED Navi...       Van  2.958923
# 15917  Blue dCi 200CV EDC Business , NUOVA DA IMMATRI...       Van  2.935230
# 15918        INITIALE PARIS TCe 225 EDC GPF NAVI SHZ AUX       Van  3.111099
#
#                     vat        km registration         prev_owner  kW  ...  \
# 0        VAT deductible  0.585840      01/2016  2 previous owners NaN  ...
# 1      Price negotiable  1.228011      03/2017                NaN NaN  ...
# 2        VAT deductible  1.320373      02/2016   1 previous owner NaN  ...
# 3                   NaN  1.040610      08/2016   1 previous owner NaN  ...
# 4                   NaN -0.480019      05/2016   1 previous owner NaN  ...
# ...                 ...       ...          ...                ...  ..  ...
# 15914    VAT deductible       NaN          -/-                NaN NaN  ...
# 15915    VAT deductible -0.648680      01/2019   1 previous owner NaN  ...
# 15916    VAT deductible -0.913317      03/2019   1 previous owner NaN  ...
# 15917    VAT deductible -0.913451      06/2019                NaN NaN  ...
# 15918    VAT deductible       NaN      01/2019   1 previous owner NaN  ...
#
#                                              description     Emission Label  \
# 0      ['\n', 'Sicherheit:', ' ', 'Deaktivierung für ...                NaN
# 1      ['\nLangstreckenfahrzeug daher die hohe Kilome...  ['\n4 (Green)\n']
# 2      ['\n', 'Fahrzeug-Nummer: AM-95365', ' ', 'Ehem...  ['\n4 (Green)\n']
# 3      ['\nAudi A1: ', '- 1e eigenaar ', '- Perfecte ...                NaN
# 4      ['\n', 'Technik & Sicherheit:', 'Xenon plus', ...                NaN
# ...                                                  ...                ...
# 15914  ['\nVettura visionabile nella sede in Via Roma...                NaN
# 15915  ['\nDach: Panorama-Glas-Schiebedach, Lackierun...                NaN
# 15916  ['\n', 'Getriebe:', ' Automatik', 'Technik:', ...                NaN
# 15917  ['\nDEK:[2691331]', 'Renault Espace Blue dCi 2...                NaN
# 15918  ['\n', 'Sicherheit Airbags:', ' ', 'Seitenairb...  ['\n4 (Green)\n']
#
#            Gears  Country version Electricity consumption Last Service Date  \
# 0            NaN              NaN                     NaN               NaN
# 1      ['\n7\n']              NaN                     NaN               NaN
# 2            NaN              NaN                     NaN               NaN
# 3      ['\n6\n']              NaN                     NaN               NaN
# 4            NaN  ['\nGermany\n']                     NaN               NaN
# ...          ...              ...                     ...               ...
# 15914  ['\n6\n']              NaN                     NaN               NaN
# 15915  ['\n7\n']  ['\nGermany\n']                     NaN               NaN
# 15916  ['\n6\n']  ['\nAustria\n']                     NaN               NaN
# 15917  ['\n6\n']              NaN                     NaN               NaN
# 15918        NaN  ['\nGermany\n']                     NaN               NaN
#
#       Other Fuel Types                   Availability  \
# 0                  NaN                            NaN
# 1                  NaN                            NaN
# 2                  NaN                            NaN
# 3                  NaN                            NaN
# 4                  NaN                            NaN
# ...                ...                            ...
# 15914              NaN                            NaN
# 15915     [[], [], []]    \nin 5 days from ordering\n
# 15916              NaN  \nin 120 days from ordering\n
# 15917              NaN                            NaN
# 15918              NaN                            NaN
#
#       Last Timing Belt Service Date Available from
# 0                               NaN            NaN
# 1                               NaN            NaN
# 2                               NaN            NaN
# 3                               NaN            NaN
# 4                               NaN            NaN
# ...                             ...            ...
# 15914                           NaN            NaN
# 15915                           NaN            NaN
# 15916                           NaN            NaN
# 15917                           NaN            NaN
# 15918                           NaN            NaN
#
# [15919 rows x 54 columns]

# %% [markdown]
# ***Convert string fields like registration into proper datetime objects. ***

# %%
# prompt: write code for 	Convert string fields like registration into proper datetime objects.

import pandas as pd

# Assuming 'data1' is your DataFrame
# Convert 'registration' column to datetime objects
if 'registration' in data1.columns:
    try:
        data1['registration'] = pd.to_datetime(data1['registration'], errors='coerce')
    except Exception as e:
        print(f"Error converting 'registration' column to datetime: {e}")
else:
    print("'registration' column not found in the DataFrame.")

data1
# Out:
# <ipython-input-46-5e7dcc6d4db7>:9: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data1['registration'] = pd.to_datetime(data1['registration'], errors='coerce')
#                                                      url      make_model  \
# 0      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 1      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 2      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 3      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 4      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# ...                                                  ...             ...
# 15914  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15915  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15916  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15917  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15918  https://www.autoscout24.com//offers/renault-es...  Renault Espace
#
#                                        short_description body_type     price  \
# 0            Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans -0.304609
# 1                                         1.8 TFSI sport    Sedans -0.476552
# 2      Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans -0.457598
# 3                                1.4 TDi Design S tronic    Sedans -0.476552
# 4      Sportback 1.4 TDI S-Tronic S-Line Ext. admired...    Sedans -0.166513
# ...                                                  ...       ...       ...
# 15914              Blue dCi 200CV EDC Executive 4Control       Van  2.969077
# 15915                TCe 225 EDC GPF LIM Deluxe Pano,RFK       Van  2.960276
# 15916  Blue dCi 200 EDC Initiale Paris Leder LED Navi...       Van  2.958923
# 15917  Blue dCi 200CV EDC Business , NUOVA DA IMMATRI...       Van  2.935230
# 15918        INITIALE PARIS TCe 225 EDC GPF NAVI SHZ AUX       Van  3.111099
#
#                     vat        km registration         prev_owner  kW  ...  \
# 0        VAT deductible  0.585840   2016-01-01  2 previous owners NaN  ...
# 1      Price negotiable  1.228011   2017-03-01                NaN NaN  ...
# 2        VAT deductible  1.320373   2016-02-01   1 previous owner NaN  ...
# 3                   NaN  1.040610   2016-08-01   1 previous owner NaN  ...
# 4                   NaN -0.480019   2016-05-01   1 previous owner NaN  ...
# ...                 ...       ...          ...                ...  ..  ...
# 15914    VAT deductible       NaN          NaT                NaN NaN  ...
# 15915    VAT deductible -0.648680   2019-01-01   1 previous owner NaN  ...
# 15916    VAT deductible -0.913317   2019-03-01   1 previous owner NaN  ...
# 15917    VAT deductible -0.913451   2019-06-01                NaN NaN  ...
# 15918    VAT deductible       NaN   2019-01-01   1 previous owner NaN  ...
#
#                                              description     Emission Label  \
# 0      ['\n', 'Sicherheit:', ' ', 'Deaktivierung für ...                NaN
# 1      ['\nLangstreckenfahrzeug daher die hohe Kilome...  ['\n4 (Green)\n']
# 2      ['\n', 'Fahrzeug-Nummer: AM-95365', ' ', 'Ehem...  ['\n4 (Green)\n']
# 3      ['\nAudi A1: ', '- 1e eigenaar ', '- Perfecte ...                NaN
# 4      ['\n', 'Technik & Sicherheit:', 'Xenon plus', ...                NaN
# ...                                                  ...                ...
# 15914  ['\nVettura visionabile nella sede in Via Roma...                NaN
# 15915  ['\nDach: Panorama-Glas-Schiebedach, Lackierun...                NaN
# 15916  ['\n', 'Getriebe:', ' Automatik', 'Technik:', ...                NaN
# 15917  ['\nDEK:[2691331]', 'Renault Espace Blue dCi 2...                NaN
# 15918  ['\n', 'Sicherheit Airbags:', ' ', 'Seitenairb...  ['\n4 (Green)\n']
#
#            Gears  Country version Electricity consumption Last Service Date  \
# 0            NaN              NaN                     NaN               NaN
# 1      ['\n7\n']              NaN                     NaN               NaN
# 2            NaN              NaN                     NaN               NaN
# 3      ['\n6\n']              NaN                     NaN               NaN
# 4            NaN  ['\nGermany\n']                     NaN               NaN
# ...          ...              ...                     ...               ...
# 15914  ['\n6\n']              NaN                     NaN               NaN
# 15915  ['\n7\n']  ['\nGermany\n']                     NaN               NaN
# 15916  ['\n6\n']  ['\nAustria\n']                     NaN               NaN
# 15917  ['\n6\n']              NaN                     NaN               NaN
# 15918        NaN  ['\nGermany\n']                     NaN               NaN
#
#       Other Fuel Types                   Availability  \
# 0                  NaN                            NaN
# 1                  NaN                            NaN
# 2                  NaN                            NaN
# 3                  NaN                            NaN
# 4                  NaN                            NaN
# ...                ...                            ...
# 15914              NaN                            NaN
# 15915     [[], [], []]    \nin 5 days from ordering\n
# 15916              NaN  \nin 120 days from ordering\n
# 15917              NaN                            NaN
# 15918              NaN                            NaN
#
#       Last Timing Belt Service Date Available from
# 0                               NaN            NaN
# 1                               NaN            NaN
# 2                               NaN            NaN
# 3                               NaN            NaN
# 4                               NaN            NaN
# ...                             ...            ...
# 15914                           NaN            NaN
# 15915                           NaN            NaN
# 15916                           NaN            NaN
# 15917                           NaN            NaN
# 15918                           NaN            NaN
#
# [15919 rows x 54 columns]

# %% [markdown]
# ***Calculate mean, median, and standard deviation for price and km. ***

# %%
# prompt: write code for Calculate mean, median, and standard deviation for price and km.

import pandas as pd

# Assuming 'data1' is your DataFrame
if 'price' in data1.columns and 'km' in data1.columns:
    # Calculate mean, median, and standard deviation for 'price'
    price_mean = data1['price'].mean()
    price_median = data1['price'].median()
    price_std = data1['price'].std()

    # Calculate mean, median, and standard deviation for 'km'
    km_mean = data1['km'].mean()
    km_median = data1['km'].median()
    km_std = data1['km'].std()

    print("Price Statistics:")
    print(f"Mean: {price_mean}")
    print(f"Median: {price_median}")
    print(f"Standard Deviation: {price_std}")

    print("\nKilometer Statistics:")
    print(f"Mean: {km_mean}")
    print(f"Median: {km_median}")
    print(f"Standard Deviation: {km_std}")
else:
    print("Error: 'price' or 'km' column not found in the DataFrame.")
# Out:
# Price Statistics:
# Mean: 2.1424744843573598e-17
# Median: -0.1516207746105518
# Standard Deviation: 1.0000000000000002
#
# Kilometer Statistics:
# Mean: 6.106040293876658e-17
# Median: -0.30493225894198434
# Standard Deviation: 1.0000000000000013

# %% [markdown]
# *** Count the frequency of each make_model***.

# %%
# prompt: write code for Count the frequency of each make_model.

import pandas as pd

# Assuming 'data1' is your DataFrame from the previous code
make_model_counts = data1['make_model'].value_counts()
make_model_counts
# Out:
# make_model
# Audi A3           3097
# Audi A1           2614
# Opel Insignia     2598
# Opel Astra        2526
# Opel Corsa        2219
# Renault Clio      1839
# Renault Espace     991
# Renault Duster      34
# Audi A2              1
# Name: count, dtype: int64

# %% [markdown]
# ***Plot the distribution of price and km. ***

# %%
# prompt: write code for  Plot the distribution of price and km.

import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'data1' is your DataFrame from the previous code
if 'price' in data1.columns and 'km' in data1.columns:
    plt.figure(figsize=(12, 6))

    # Distribution of Price
    plt.subplot(1, 2, 1)
    sns.histplot(data1['price'], kde=True)
    plt.title('Distribution of Price')
    plt.xlabel('Price')
    plt.ylabel('Frequency')

    # Distribution of km
    plt.subplot(1, 2, 2)
    sns.histplot(data1['km'], kde=True)
    plt.title('Distribution of Kilometer')
    plt.xlabel('Kilometer')
    plt.ylabel('Frequency')

    plt.tight_layout()
    plt.show()
else:
    print("Error: 'price' or 'km' column not found in the DataFrame.")

# %% [markdown]
# *** Analyze the average price by body_type.***

# %%
# prompt: write code for Analyze the average price by body_type.

# Assuming 'data1' is your DataFrame from the previous code
if 'price' in data1.columns and 'body_type' in data1.columns:
    average_price_by_body_type = data1.groupby('body_type')['price'].mean()
    print(average_price_by_body_type)
else:
    print("Error: 'price' or 'body_type' column not found in the DataFrame.")
# Out:
# body_type
# Compact         -0.379582
# Convertible      1.338377
# Coupe           -0.514093
# Off-Road        -0.121001
# Other           -0.515843
# Sedans          -0.038449
# Station wagon    0.084399
# Transporter     -0.169926
# Van              1.736588
# Name: price, dtype: float64

# %% [markdown]
# *** Identify correlations between numerical variables, such as price and km***.

# %%
# prompt:  Identify correlations between numerical variables, such as price and km.

# Assuming 'data1' is your DataFrame from the previous code
if 'price' in data1.columns and 'km' in data1.columns:
    correlation = data1['price'].corr(data1['km'])
    print(f"Correlation between price and km: {correlation}")

    # Create a scatter plot to visualize the correlation
    plt.figure(figsize=(8, 6))
    sns.scatterplot(x='km', y='price', data=data1)
    plt.title('Correlation between Price and Kilometer')
    plt.xlabel('Kilometer')
    plt.ylabel('Price')
    plt.show()
else:
    print("Error: 'price' or 'km' column not found in the DataFrame.")
# Out:
# Correlation between price and km: -0.38782119044007735

# %% [markdown]
#  ***Create a scatter plot to show the relationship between price and km. ***

# %%
# prompt: write code for Create a scatter plot to show the relationship between price and km.

import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'data1' is your DataFrame from the previous code
if 'price' in data1.columns and 'km' in data1.columns:
    plt.figure(figsize=(8, 6))
    sns.scatterplot(x='km', y='price', data=data1)
    plt.title('Correlation between Price and Kilometer')
    plt.xlabel('Kilometer')
    plt.ylabel('Price')
    plt.show()

    correlation = data1['price'].corr(data1['km'])
    print(f"Correlation coefficient between price and km: {correlation}")
else:
    print("Error: 'price' or 'km' column not found in the DataFrame.")
# Out:
# Correlation coefficient between price and km: -0.38782119044007735

# %% [markdown]
# ***Use a bar chart to compare the average price of different body_type. ***

# %%
# prompt: write a code for Use a bar chart to compare the average price of different body_type.

import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'data1' is your DataFrame from the previous code
if 'price' in data1.columns and 'body_type' in data1.columns:
    average_price_by_body_type = data1.groupby('body_type')['price'].mean()

    plt.figure(figsize=(10, 6))
    sns.barplot(x=average_price_by_body_type.index, y=average_price_by_body_type.values)
    plt.title('Average Price by Body Type')
    plt.xlabel('Body Type')
    plt.ylabel('Average Price')
    plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
    plt.tight_layout()
    plt.show()
else:
    print("Error: 'price' or 'body_type' column not found in the DataFrame.")

# %% [markdown]
# *** Display a pie chart for the proportion of different make_model.***

# %%
# prompt: write a code for Display a pie chart for the proportion of different make_model.

import matplotlib.pyplot as plt

# Assuming 'data1' is your DataFrame from the previous code
if 'make_model' in data1.columns:
    make_model_counts = data1['make_model'].value_counts()

    # Create the pie chart
    plt.figure(figsize=(10, 8))  # Adjust figure size as needed
    plt.pie(make_model_counts, labels=make_model_counts.index, autopct='%1.1f%%', startangle=90)
    plt.title('Proportion of Different Make Models')
    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.show()
else:
    print("Error: 'make_model' column not found in the DataFrame.")

# %% [markdown]
# ***Create a new column for the age of the car using the registration field. ***

# %%
# prompt: write a code for Create a new column for the age of the car using the registration field.

import pandas as pd

# Assuming 'data1' is your DataFrame from the previous code
if 'registration' in data1.columns:
    try:
        # Convert the 'registration' column to datetime objects
        data1['registration'] = pd.to_datetime(data1['registration'], errors='coerce')

        # Calculate the age of the car in years (as of today's date)
        current_year = pd.Timestamp.now().year
        data1['car_age'] = current_year - data1['registration'].dt.year

        # Handle cases where registration year is in the future
        data1['car_age'] = data1['car_age'].apply(lambda x: max(0, x))

    except Exception as e:
        print(f"Error calculating car age: {e}")
else:
    print("'registration' column not found in the DataFrame.")

data1
# Out:
#                                                      url      make_model  \
# 0      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 1      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 2      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 3      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 4      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# ...                                                  ...             ...
# 15914  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15915  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15916  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15917  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15918  https://www.autoscout24.com//offers/renault-es...  Renault Espace
#
#                                        short_description body_type     price  \
# 0            Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans -0.304609
# 1                                         1.8 TFSI sport    Sedans -0.476552
# 2      Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans -0.457598
# 3                                1.4 TDi Design S tronic    Sedans -0.476552
# 4      Sportback 1.4 TDI S-Tronic S-Line Ext. admired...    Sedans -0.166513
# ...                                                  ...       ...       ...
# 15914              Blue dCi 200CV EDC Executive 4Control       Van  2.969077
# 15915                TCe 225 EDC GPF LIM Deluxe Pano,RFK       Van  2.960276
# 15916  Blue dCi 200 EDC Initiale Paris Leder LED Navi...       Van  2.958923
# 15917  Blue dCi 200CV EDC Business , NUOVA DA IMMATRI...       Van  2.935230
# 15918        INITIALE PARIS TCe 225 EDC GPF NAVI SHZ AUX       Van  3.111099
#
#                     vat        km registration         prev_owner  kW  ...  \
# 0        VAT deductible  0.585840   2016-01-01  2 previous owners NaN  ...
# 1      Price negotiable  1.228011   2017-03-01                NaN NaN  ...
# 2        VAT deductible  1.320373   2016-02-01   1 previous owner NaN  ...
# 3                   NaN  1.040610   2016-08-01   1 previous owner NaN  ...
# 4                   NaN -0.480019   2016-05-01   1 previous owner NaN  ...
# ...                 ...       ...          ...                ...  ..  ...
# 15914    VAT deductible       NaN          NaT                NaN NaN  ...
# 15915    VAT deductible -0.648680   2019-01-01   1 previous owner NaN  ...
# 15916    VAT deductible -0.913317   2019-03-01   1 previous owner NaN  ...
# 15917    VAT deductible -0.913451   2019-06-01                NaN NaN  ...
# 15918    VAT deductible       NaN   2019-01-01   1 previous owner NaN  ...
#
#           Emission Label      Gears  Country version Electricity consumption  \
# 0                    NaN        NaN              NaN                     NaN
# 1      ['\n4 (Green)\n']  ['\n7\n']              NaN                     NaN
# 2      ['\n4 (Green)\n']        NaN              NaN                     NaN
# 3                    NaN  ['\n6\n']              NaN                     NaN
# 4                    NaN        NaN  ['\nGermany\n']                     NaN
# ...                  ...        ...              ...                     ...
# 15914                NaN  ['\n6\n']              NaN                     NaN
# 15915                NaN  ['\n7\n']  ['\nGermany\n']                     NaN
# 15916                NaN  ['\n6\n']  ['\nAustria\n']                     NaN
# 15917                NaN  ['\n6\n']              NaN                     NaN
# 15918  ['\n4 (Green)\n']        NaN  ['\nGermany\n']                     NaN
#
#       Last Service Date Other Fuel Types                   Availability  \
# 0                   NaN              NaN                            NaN
# 1                   NaN              NaN                            NaN
# 2                   NaN              NaN                            NaN
# 3                   NaN              NaN                            NaN
# 4                   NaN              NaN                            NaN
# ...                 ...              ...                            ...
# 15914               NaN              NaN                            NaN
# 15915               NaN     [[], [], []]    \nin 5 days from ordering\n
# 15916               NaN              NaN  \nin 120 days from ordering\n
# 15917               NaN              NaN                            NaN
# 15918               NaN              NaN                            NaN
#
#       Last Timing Belt Service Date Available from car_age
# 0                               NaN            NaN     8.0
# 1                               NaN            NaN     7.0
# 2                               NaN            NaN     8.0
# 3                               NaN            NaN     8.0
# 4                               NaN            NaN     8.0
# ...                             ...            ...     ...
# 15914                           NaN            NaN     0.0
# 15915                           NaN            NaN     5.0
# 15916                           NaN            NaN     5.0
# 15917                           NaN            NaN     5.0
# 15918                           NaN            NaN     5.0
#
# [15919 rows x 55 columns]

# %% [markdown]
# *** Generate a price_per_km column to assess cost efficiency.***

# %%
# prompt: write a code for Generate a price_per_km column to assess cost efficiency.

# Assuming 'data1' is your DataFrame from the previous code
if 'price' in data1.columns and 'km' in data1.columns:
    # Calculate price_per_km
    data1['price_per_km'] = data1['price'] / data1['km']

    # Display the updated DataFrame
    print(data1)
else:
    print("Error: 'price' or 'km' column not found in the DataFrame.")
# Out:
#                                                      url      make_model  \
# 0      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 1      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 2      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 3      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 4      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# ...                                                  ...             ...
# 15914  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15915  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15916  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15917  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15918  https://www.autoscout24.com//offers/renault-es...  Renault Espace
#
#                                        short_description body_type     price  \
# 0            Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans -0.304609
# 1                                         1.8 TFSI sport    Sedans -0.476552
# 2      Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans -0.457598
# 3                                1.4 TDi Design S tronic    Sedans -0.476552
# 4      Sportback 1.4 TDI S-Tronic S-Line Ext. admired...    Sedans -0.166513
# ...                                                  ...       ...       ...
# 15914              Blue dCi 200CV EDC Executive 4Control       Van  2.969077
# 15915                TCe 225 EDC GPF LIM Deluxe Pano,RFK       Van  2.960276
# 15916  Blue dCi 200 EDC Initiale Paris Leder LED Navi...       Van  2.958923
# 15917  Blue dCi 200CV EDC Business , NUOVA DA IMMATRI...       Van  2.935230
# 15918        INITIALE PARIS TCe 225 EDC GPF NAVI SHZ AUX       Van  3.111099
#
#                     vat        km registration         prev_owner  kW  ...  \
# 0        VAT deductible  0.585840   2016-01-01  2 previous owners NaN  ...
# 1      Price negotiable  1.228011   2017-03-01                NaN NaN  ...
# 2        VAT deductible  1.320373   2016-02-01   1 previous owner NaN  ...
# 3                   NaN  1.040610   2016-08-01   1 previous owner NaN  ...
# 4                   NaN -0.480019   2016-05-01   1 previous owner NaN  ...
# ...                 ...       ...          ...                ...  ..  ...
# 15914    VAT deductible       NaN          NaT                NaN NaN  ...
# 15915    VAT deductible -0.648680   2019-01-01   1 previous owner NaN  ...
# 15916    VAT deductible -0.913317   2019-03-01   1 previous owner NaN  ...
# 15917    VAT deductible -0.913451   2019-06-01                NaN NaN  ...
# 15918    VAT deductible       NaN   2019-01-01   1 previous owner NaN  ...
#
#            Gears  Country version Electricity consumption Last Service Date  \
# 0            NaN              NaN                     NaN               NaN
# 1      ['\n7\n']              NaN                     NaN               NaN
# 2            NaN              NaN                     NaN               NaN
# 3      ['\n6\n']              NaN                     NaN               NaN
# 4            NaN  ['\nGermany\n']                     NaN               NaN
# ...          ...              ...                     ...               ...
# 15914  ['\n6\n']              NaN                     NaN               NaN
# 15915  ['\n7\n']  ['\nGermany\n']                     NaN               NaN
# 15916  ['\n6\n']  ['\nAustria\n']                     NaN               NaN
# 15917  ['\n6\n']              NaN                     NaN               NaN
# 15918        NaN  ['\nGermany\n']                     NaN               NaN
#
#       Other Fuel Types                   Availability  \
# 0                  NaN                            NaN
# 1                  NaN                            NaN
# 2                  NaN                            NaN
# 3                  NaN                            NaN
# 4                  NaN                            NaN
# ...                ...                            ...
# 15914              NaN                            NaN
# 15915     [[], [], []]    \nin 5 days from ordering\n
# 15916              NaN  \nin 120 days from ordering\n
# 15917              NaN                            NaN
# 15918              NaN                            NaN
#
#       Last Timing Belt Service Date Available from car_age price_per_km
# 0                               NaN            NaN     8.0    -0.519953
# 1                               NaN            NaN     7.0    -0.388068
# 2                               NaN            NaN     8.0    -0.346567
# 3                               NaN            NaN     8.0    -0.457955
# 4                               NaN            NaN     8.0     0.346890
# ...                             ...            ...     ...          ...
# 15914                           NaN            NaN     0.0          NaN
# 15915                           NaN            NaN     5.0    -4.563539
# 15916                           NaN            NaN     5.0    -3.239752
# 15917                           NaN            NaN     5.0    -3.213340
# 15918                           NaN            NaN     5.0          NaN
#
# [15919 rows x 56 columns]

# %% [markdown]
# ***Create categories for cars based on price (e.g., low, mid, high).***

# %%
# prompt: write code for Create categories for cars based on price (e.g., low, mid, high).

# Assuming 'data1' is your DataFrame from the previous code
if 'price' in data1.columns:
    # Define price thresholds for categories
    low_threshold = data1['price'].quantile(0.33)  # 33rd percentile
    high_threshold = data1['price'].quantile(0.66)  # 66th percentile

    # Create a new 'price_category' column
    data1['price_category'] = pd.cut(data1['price'], bins=[-float('inf'), low_threshold, high_threshold, float('inf')],
                                      labels=['low', 'mid', 'high'])
    print(data1[['price', 'price_category']]) # Print the relevant columns
else:
    print("Error: 'price' column not found in the DataFrame.")
# Out:
#           price price_category
# 0     -0.304609            mid
# 1     -0.476552            mid
# 2     -0.457598            mid
# 3     -0.476552            mid
# 4     -0.166513            mid
# ...         ...            ...
# 15914  2.969077           high
# 15915  2.960276           high
# 15916  2.958923           high
# 15917  2.935230           high
# 15918  3.111099           high
#
# [15919 rows x 2 columns]

# %% [markdown]
# **Identify vehicles with specific features such as “VAT deductible”.**

# %%
# prompt: Find the average price and mileage for VAT-deductible vehicles.

# Assuming 'data1' is your DataFrame from the previous code
if 'vat' in data1.columns:
    # Filter for VAT-deductible vehicles
    vat_deductible_vehicles = data1[data1['vat'] == True]

    # Calculate the average price and mileage for these vehicles
    average_price = vat_deductible_vehicles['price'].mean()
    average_mileage = vat_deductible_vehicles['km'].mean()

    print(f"Average price for VAT-deductible vehicles: {average_price}")
    print(f"Average mileage for VAT-deductible vehicles: {average_mileage}")
else:
    print("Error: 'vat' column not found in the DataFrame.")
# Out:
# Average price for VAT-deductible vehicles: nan
# Average mileage for VAT-deductible vehicles: nan

# %% [markdown]
#  ***Identify the most common car models in the dataset.***

# %%
# prompt: write code for Identify the most common car models in the dataset.

# Assuming 'data1' is your DataFrame from the previous code
if 'make_model' in data1.columns:
    most_common_models = data1['make_model'].value_counts().head(10)  # Get the top 10 most common models
    print(most_common_models)
else:
    print("Error: 'make_model' column not found in the DataFrame.")
# Out:
# make_model
# Audi A3           3097
# Audi A1           2614
# Opel Insignia     2598
# Opel Astra        2526
# Opel Corsa        2219
# Renault Clio      1839
# Renault Espace     991
# Renault Duster      34
# Audi A2              1
# Name: count, dtype: int64

# %% [markdown]
# *** Highlight the cars that provide the best value for money (low price_per_km). ***

# %%
# prompt: write code for Highlight the cars that provide the best value for money (low price_per_km).

# Assuming 'data1' is your DataFrame from the previous code
if 'price_per_km' in data1.columns:
    # Calculate the threshold for "best value" (e.g., bottom 25th percentile)
    threshold = data1['price_per_km'].quantile(0.25)

    # Highlight cars with price_per_km below the threshold
    data1['Best Value'] = data1['price_per_km'] < threshold

    # Display the DataFrame with the highlighted cars
    print(data1)
else:
    print("Error: 'price_per_km' column not found in the DataFrame.  Make sure you've calculated it first.")
# Out:
#                                                      url      make_model  \
# 0      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 1      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 2      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 3      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 4      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# ...                                                  ...             ...
# 15914  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15915  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15916  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15917  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15918  https://www.autoscout24.com//offers/renault-es...  Renault Espace
#
#                                        short_description body_type     price  \
# 0            Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans -0.304609
# 1                                         1.8 TFSI sport    Sedans -0.476552
# 2      Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans -0.457598
# 3                                1.4 TDi Design S tronic    Sedans -0.476552
# 4      Sportback 1.4 TDI S-Tronic S-Line Ext. admired...    Sedans -0.166513
# ...                                                  ...       ...       ...
# 15914              Blue dCi 200CV EDC Executive 4Control       Van  2.969077
# 15915                TCe 225 EDC GPF LIM Deluxe Pano,RFK       Van  2.960276
# 15916  Blue dCi 200 EDC Initiale Paris Leder LED Navi...       Van  2.958923
# 15917  Blue dCi 200CV EDC Business , NUOVA DA IMMATRI...       Van  2.935230
# 15918        INITIALE PARIS TCe 225 EDC GPF NAVI SHZ AUX       Van  3.111099
#
#                     vat        km registration         prev_owner  kW  ...  \
# 0        VAT deductible  0.585840   2016-01-01  2 previous owners NaN  ...
# 1      Price negotiable  1.228011   2017-03-01                NaN NaN  ...
# 2        VAT deductible  1.320373   2016-02-01   1 previous owner NaN  ...
# 3                   NaN  1.040610   2016-08-01   1 previous owner NaN  ...
# 4                   NaN -0.480019   2016-05-01   1 previous owner NaN  ...
# ...                 ...       ...          ...                ...  ..  ...
# 15914    VAT deductible       NaN          NaT                NaN NaN  ...
# 15915    VAT deductible -0.648680   2019-01-01   1 previous owner NaN  ...
# 15916    VAT deductible -0.913317   2019-03-01   1 previous owner NaN  ...
# 15917    VAT deductible -0.913451   2019-06-01                NaN NaN  ...
# 15918    VAT deductible       NaN   2019-01-01   1 previous owner NaN  ...
#
#       Electricity consumption Last Service Date Other Fuel Types  \
# 0                         NaN               NaN              NaN
# 1                         NaN               NaN              NaN
# 2                         NaN               NaN              NaN
# 3                         NaN               NaN              NaN
# 4                         NaN               NaN              NaN
# ...                       ...               ...              ...
# 15914                     NaN               NaN              NaN
# 15915                     NaN               NaN     [[], [], []]
# 15916                     NaN               NaN              NaN
# 15917                     NaN               NaN              NaN
# 15918                     NaN               NaN              NaN
#
#                         Availability Last Timing Belt Service Date  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN                           NaN
# 3                                NaN                           NaN
# 4                                NaN                           NaN
# ...                              ...                           ...
# 15914                            NaN                           NaN
# 15915    \nin 5 days from ordering\n                           NaN
# 15916  \nin 120 days from ordering\n                           NaN
# 15917                            NaN                           NaN
# 15918                            NaN                           NaN
#
#       Available from car_age price_per_km price_category Best Value
# 0                NaN     8.0    -0.519953            mid      False
# 1                NaN     7.0    -0.388068            mid      False
# 2                NaN     8.0    -0.346567            mid      False
# 3                NaN     8.0    -0.457955            mid      False
# 4                NaN     8.0     0.346890            mid      False
# ...              ...     ...          ...            ...        ...
# 15914            NaN     0.0          NaN           high      False
# 15915            NaN     5.0    -4.563539           high       True
# 15916            NaN     5.0    -3.239752           high       True
# 15917            NaN     5.0    -3.213340           high       True
# 15918            NaN     5.0          NaN           high      False
#
# [15919 rows x 58 columns]

# %% [markdown]
# *** Group the vehicles based on attributes like price, km, and age.     give code for step by step  ***

# %%
# prompt: write code for Group the vehicles based on attributes like price, km, and age.     give code for step by step

# Assuming 'data1' is your DataFrame from the previous code
# and it contains 'price', 'km', and 'car_age' columns.

if 'price' in data1.columns and 'km' in data1.columns and 'car_age' in data1.columns:
    # Define price, km, and age ranges for grouping
    price_bins = [0, 10000, 20000, 30000, float('inf')]  # Example price bins
    km_bins = [0, 50000, 100000, 150000, float('inf')]  # Example km bins
    age_bins = [0, 2, 5, 10, float('inf')]  # Example age bins

    # Create labels for the bins
    price_labels = ['Low', 'Mid', 'High', 'Very High']
    km_labels = ['Low', 'Mid', 'High', 'Very High']
    age_labels = ['New', 'Young', 'Mature', 'Old']

    # Create categorical columns based on bins
    data1['price_group'] = pd.cut(data1['price'], bins=price_bins, labels=price_labels, right=False)
    data1['km_group'] = pd.cut(data1['km'], bins=km_bins, labels=km_labels, right=False)
    data1['age_group'] = pd.cut(data1['car_age'], bins=age_bins, labels=age_labels, right=False)

    # Group vehicles based on the categorical columns
    grouped_vehicles = data1.groupby(['price_group', 'km_group', 'age_group'])

    # Print or further analyze the grouped data
    for (price_cat, km_cat, age_cat), group in grouped_vehicles:
        print(f"\nPrice Group: {price_cat}, KM Group: {km_cat}, Age Group: {age_cat}")
        print(group) #Prints each group
else:
    print("Error: 'price', 'km', or 'car_age' column not found in the DataFrame.")
# Out:
# Price Group: Low, KM Group: Low, Age Group: Mature
#                                                      url      make_model  \
# 13     https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 18     https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 20     https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 65     https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 66     https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# ...                                                  ...             ...
# 15640  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15641  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15647  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15648  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15711  https://www.autoscout24.com//offers/renault-es...  Renault Espace
#
#                                        short_description body_type     price  \
# 13           1.4 TFSI 150ch COD Ambition Luxe S tronic 7    Sedans  0.051326
# 18                      1.0 TFSI 95pk Automaat Adrenalin   Compact  0.051461
# 20            SPB 1.6 TDI 116 CV S tronic Admired S-Line    Sedans  0.065000
# 65     Sportback 1.0 TFSI Adrenalin * AUTOMAAT * S-LI...   Compact  0.119156
# 66                  Sportback Dsl 1.6 TDi Sport S tronic    Sedans  0.119156
# ...                                                  ...       ...       ...
# 15640   1.6 dCi EDC 7persoons Initiale Paris / Schuifdak       Van  1.417528
# 15641                        V dCi 160 Energy Twin Turbo       Van  1.527193
# 15647                        V dCi 160 Energy Twin Turbo       Van  1.417528
# 15648                        dCi 160CV EDC Energy Intens       Van  1.378266
# 15711            1.8 Energy TCe 225pk EDC GPF 7PL Intens       Van  2.630606
#
#                     vat        km registration        prev_owner  kW  ...  \
# 13                  NaN  0.311458   2016-06-01               NaN NaN  ...
# 18       VAT deductible  0.432358   2016-07-01               NaN NaN  ...
# 20     Price negotiable  0.455917   2017-06-01  1 previous owner NaN  ...
# 65                  NaN  0.191789   2016-11-01               NaN NaN  ...
# 66                  NaN  0.799665   2017-06-01               NaN NaN  ...
# ...                 ...       ...          ...               ...  ..  ...
# 15640               NaN  1.817014   2017-02-01               NaN NaN  ...
# 15641    VAT deductible  0.601153   2017-11-01               NaN NaN  ...
# 15647    VAT deductible  0.472409   2017-11-01               NaN NaN  ...
# 15648               NaN  0.191949   2017-01-01  1 previous owner NaN  ...
# 15711    VAT deductible  0.769145   2018-01-01               NaN NaN  ...
#
#       Availability Last Timing Belt Service Date Available from car_age  \
# 13             NaN                           NaN            NaN     8.0
# 18             NaN                           NaN            NaN     8.0
# 20             NaN                           NaN            NaN     7.0
# 65             NaN                           NaN            NaN     8.0
# 66             NaN                           NaN            NaN     7.0
# ...            ...                           ...            ...     ...
# 15640          NaN                           NaN            NaN     7.0
# 15641          NaN                           NaN            NaN     7.0
# 15647          NaN                           NaN            NaN     7.0
# 15648          NaN                           NaN            NaN     7.0
# 15711          NaN                           NaN            NaN     6.0
#
#       price_per_km price_category Best Value price_group km_group age_group
# 13        0.164793            mid      False         Low      Low    Mature
# 18        0.119025            mid      False         Low      Low    Mature
# 20        0.142570            mid      False         Low      Low    Mature
# 65        0.621286            mid      False         Low      Low    Mature
# 66        0.149007            mid      False         Low      Low    Mature
# ...            ...            ...        ...         ...      ...       ...
# 15640     0.780142           high      False         Low      Low    Mature
# 15641     2.540437           high      False         Low      Low    Mature
# 15647     3.000639           high      False         Low      Low    Mature
# 15648     7.180369           high      False         Low      Low    Mature
# 15711     3.420168           high      False         Low      Low    Mature
#
# [834 rows x 61 columns]
# <ipython-input-68-4087538d894e>:23: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vehicles = data1.groupby(['price_group', 'km_group', 'age_group'])
